# %%
import seaborn as sns
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %%
unclean_titanic_data = sns.load_dataset('titanic')
pd.options.display.float_format = "{:,.2f}".format

# %%
unclean_titanic_data.head(50)
# Out:
#     survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 0          0       3    male 22.00      1      0   7.25        S   Third
# 1          1       1  female 38.00      1      0  71.28        C   First
# 2          1       3  female 26.00      0      0   7.92        S   Third
# 3          1       1  female 35.00      1      0  53.10        S   First
# 4          0       3    male 35.00      0      0   8.05        S   Third
# 5          0       3    male   nan      0      0   8.46        Q   Third
# 6          0       1    male 54.00      0      0  51.86        S   First
# 7          0       3    male  2.00      3      1  21.07        S   Third
# 8          1       3  female 27.00      0      2  11.13        S   Third
# 9          1       2  female 14.00      1      0  30.07        C  Second
# 10         1       3  female  4.00      1      1  16.70        S   Third
# 11         1       1  female 58.00      0      0  26.55        S   First
# ...

# %%
titanic_data = unclean_titanic_data.drop(["deck", "embarked", "survived", "pclass", "adult_male", "sibsp"], axis = 1)

# %%
titanic_data.isnull().any()
# Finding which columns have null values
# Out:
# sex            False
# age             True
# parch          False
# fare           False
# class          False
# who            False
# embark_town     True
# alive          False
# alone          False
# dtype: bool

# %%
titanic_data.info()
# Finding how many null values are in each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sex          891 non-null    object
#  1   age          714 non-null    float64
#  2   parch        891 non-null    int64
#  3   fare         891 non-null    float64
#  4   class        891 non-null    category
#  5   who          891 non-null    object
#  6   embark_town  889 non-null    object
#  7   alive        891 non-null    object
#  8   alone        891 non-null    bool
# dtypes: bool(1), category(1), float64(2), int64(1), object(4)
# memory usage: 50.7+ KB

# %%
titanic_data[titanic_data["embark_town"].isna()]
# finding which passengers have null values for embraked/ embarked-town
# Out:
#         sex   age  parch  fare  class    who embark_town alive  alone
# 61   female 38.00      0 80.00  First  woman         NaN   yes   True
# 829  female 62.00      0 80.00  First  woman         NaN   yes   True

# %%
titanic_data.duplicated()
titanic_data = titanic_data.drop_duplicates()
titanic_data
# Out:
#         sex   age  parch  fare  class    who  embark_town alive  alone
# 0      male 22.00      0  7.25  Third    man  Southampton    no  False
# 1    female 38.00      0 71.28  First  woman    Cherbourg   yes  False
# 2    female 26.00      0  7.92  Third  woman  Southampton   yes   True
# 3    female 35.00      0 53.10  First  woman  Southampton   yes  False
# 4      male 35.00      0  8.05  Third    man  Southampton    no   True
# ..      ...   ...    ...   ...    ...    ...          ...   ...    ...
# 885  female 39.00      5 29.12  Third  woman   Queenstown    no  False
# 887  female 19.00      0 30.00  First  woman  Southampton   yes   True
# 888  female   nan      2 23.45  Third  woman  Southampton    no  False
# 889    male 26.00      0 30.00  First    man    Cherbourg   yes   True
# 890    male 32.00      0  7.75  Third    man   Queenstown    no   True
#
# [780 rows x 9 columns]

# %%
titanic_data.drop([61, 829], axis=0)
# Out:
#         sex   age  parch  fare  class    who  embark_town alive  alone
# 0      male 22.00      0  7.25  Third    man  Southampton    no  False
# 1    female 38.00      0 71.28  First  woman    Cherbourg   yes  False
# 2    female 26.00      0  7.92  Third  woman  Southampton   yes   True
# 3    female 35.00      0 53.10  First  woman  Southampton   yes  False
# 4      male 35.00      0  8.05  Third    man  Southampton    no   True
# ..      ...   ...    ...   ...    ...    ...          ...   ...    ...
# 885  female 39.00      5 29.12  Third  woman   Queenstown    no  False
# 887  female 19.00      0 30.00  First  woman  Southampton   yes   True
# 888  female   nan      2 23.45  Third  woman  Southampton    no  False
# 889    male 26.00      0 30.00  First    man    Cherbourg   yes   True
# 890    male 32.00      0  7.75  Third    man   Queenstown    no   True
#
# [778 rows x 9 columns]

# %%
titanic_data.groupby("class", axis=0)["fare"].mean()
# Out:
# class
# First    85.16
# Second   21.89
# Third    13.67
# Name: fare, dtype: float64

# %%
titanic_data.groupby("class", axis=0)["age", "fare"].mean()
# Out:
# <ipython-input-11-931404560ab2>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   titanic_data.groupby("class", axis=0)["age", "fare"].mean()
#          age  fare
# class
# First  38.18 85.16
# Second 29.86 21.89
# Third  25.18 13.67

# %%
titanic_data.groupby("sex", axis=0)["alive"].count()
# Out:
# sex
# female    292
# male      488
# Name: alive, dtype: int64

# %%
titanic_data['fare_percentage'] = (titanic_data['fare'] / titanic_data['fare'].sum()) * 100

# %%
titanic_data
# Out:
#         sex   age  parch  fare  class    who  embark_town alive  alone  \
# 0      male 22.00      0  7.25  Third    man  Southampton    no  False
# 1    female 38.00      0 71.28  First  woman    Cherbourg   yes  False
# 2    female 26.00      0  7.92  Third  woman  Southampton   yes   True
# 3    female 35.00      0 53.10  First  woman  Southampton   yes  False
# 4      male 35.00      0  8.05  Third    man  Southampton    no   True
# ..      ...   ...    ...   ...    ...    ...          ...   ...    ...
# 885  female 39.00      5 29.12  Third  woman   Queenstown    no  False
# 887  female 19.00      0 30.00  First  woman  Southampton   yes   True
# 888  female   nan      2 23.45  Third  woman  Southampton    no  False
# 889    male 26.00      0 30.00  First    man    Cherbourg   yes   True
# 890    male 32.00      0  7.75  Third    man   Queenstown    no   True
#
#      fare_percentage
# 0               0.03
# 1               0.26
# 2               0.03
# 3               0.20
# ...

# %%
titanic_data['fare'].sum()
# Out:
# 27166.7039

# %%
titanic_data = titanic_data.rename(columns={'class':'seat_class'})

# %%
titanic_data.query('age == 20 & sex == "male" & seat_class == "Third" & alive == "no" & embark_town == "Southampton"')
# Out:
#       sex   age  parch  fare seat_class  who  embark_town alive  alone  \
# 12   male 20.00      0  8.05      Third  man  Southampton    no   True
# 91   male 20.00      0  7.85      Third  man  Southampton    no   True
# 131  male 20.00      0  7.05      Third  man  Southampton    no   True
# 441  male 20.00      0  9.50      Third  man  Southampton    no   True
# 682  male 20.00      0  9.22      Third  man  Southampton    no   True
# 725  male 20.00      0  8.66      Third  man  Southampton    no   True
# 840  male 20.00      0  7.92      Third  man  Southampton    no   True
# 876  male 20.00      0  9.85      Third  man  Southampton    no   True
#
#      fare_percentage
# 12              0.03
# 91              0.03
# 131             0.03
# 441             0.03
# 682             0.03
# 725             0.03
# 840             0.03
# 876             0.04

# %%
titanic_data.query('age == 17 & sex == "female" & seat_class == "First" & alive == "yes" & embark_town == "Southampton"')
# Out:
#         sex   age  parch  fare seat_class    who  embark_town alive  alone  \
# 781  female 17.00      0 57.00      First  woman  Southampton   yes  False
#
#      fare_percentage
# 781             0.21

# %%
titanic_data.groupby("seat_class", axis=0)["age"].mean()
# Out:
# seat_class
# First    38.18
# Second   29.86
# Third    25.18
# Name: age, dtype: float64
